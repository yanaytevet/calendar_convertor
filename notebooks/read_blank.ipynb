# %%
import fitz

# %%
filename = "cal_blank.pdf"
doc = fitz.open(filename)

# %%
page = doc[0]

# %%
page.get_text('dict')["blocks"]
# Out:
# [{'number': 0,
#   'type': 0,
#   'bbox': (81.59739685058594,
#    58.494972229003906,
#    774.6651000976562,
#    139.69943237304688),
#   'lines': [{'spans': [{'size': 9.5,
#       'flags': 16,
#       'font': 'Arial-BoldMT',
#       'color': 0,
#       'ascender': 1.0700000524520874,
#       'descender': -0.3070000112056732,
#       'text': 'םיפתתשמאשוניללכםוקימתעש םויס',
#       'origin': (140.60000610351562, 69.55999755859375),
#       'bbox': (140.60000610351562,
#        58.494972229003906,
#        672.8440551757812,
#        72.47650146484375)}],
#     'wmode': 0,
#     'dir': (1.0, 0.0),
#     'bbox': (140.60000610351562,
#      58.494972229003906,
#      672.8440551757812,
#      72.47650146484375)},
#    {'spans': [{'size': 9.5,
#       'flags': 16,
#       'font': 'Arial-BoldMT',
#       'color': 0,
#       'ascender': 1.0700000524520874,
#       'descender': -0.3070000112056732,
#       'text': 'm»v',
#       'origin': (709.4000244140625, 69.05999755859375),
# ...
